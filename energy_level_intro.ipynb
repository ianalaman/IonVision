# %%
from energy_level_generator.render import plot_from_json

plot_from_json(
    "energy_level_generator/data/SrPrepDown.json",
    "energy_level_generator/data/sr_style.json",  # or whatever you named it
    save_path="figures/sr_prep_down.png",
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 3
#       1 from energy_level_generator.render import plot_from_json
# ----> 3 plot_from_json(
#       4     "energy_level_generator/data/SrPrepDown.json",
#       5     "energy_level_generator/data/sr_style.json",  # or whatever you named it
#       6     save_path="figures/sr_prep_down.png",
#       7 )
#
# File c:\Users\iks14535\NQCC\energy_level_generator\render.py:105, in plot_from_json(levels_json_path, style_json_path, save_path, show_axis, figsize)
#     102 style_cfg = StyleConfig(**{**default_style().__dict__, **style_dict.get("style", {})})
#     104 # Plot
# --> 105 fig = plot_energy_levels(
#     106     data=data,
#     107     layout_cfg=layout_cfg,
#     108     style_cfg=style_cfg,
#     109     figsize=figsize,
#     110     show_axis=show_axis,
#     111     return_fig=True
#     112 )
# ...
