# %%
from energy_level_generator.render import plot_from_json

plot_from_json(
    "energy_level_generator/data/SrPrepDown.json",
    "energy_level_generator/data/sr_style.json",  # or whatever you named it
    save_path="figures/sr_prep_down.png",
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from energy_level_generator.render import plot_from_json
# ----> 3 plot_from_json(
#       4     "energy_level_generator/data/SrPrepDown.json",
#       5     "energy_level_generator/data/sr_style.json",  # or whatever you named it
#       6     save_path="figures/sr_prep_down.png",
#       7 )
#
# File c:\Users\iks14535\NQCC\energy_level_generator\render.py:83, in plot_from_json(levels_json_path, style_json_path, save_path, show_axis, figsize)
#      78 aliases = _build_aliases(levels)
#      79 transitions = _remap_transitions(levels_data.get("transitions", []), aliases)
#      81 data = {
#      82     "levels": levels,
# ---> 83     "transitions": raw.get("transitions", []),
#      84     "ion": levels_data.get("ion", ""),
#      85     "unit": levels_data.get("unit", "cm$^{-1}$"),
#      86     "title": levels_data.get("title", "")
#      87 }
#      89 # Load style/layout JSON if provided
#      90 style_dict = {}
#
# NameError: name 'raw' is not defined
