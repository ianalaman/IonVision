# %%
from energy_level_generator.render import generate_energy_levels

generate_energy_levels("energy.json", "energy_style.json")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from energy_level_generator.render import generate_energy_levels
#       3 generate_energy_levels("energy.json", "energy_style.json")
#
# ModuleNotFoundError: No module named 'energy_level_generator'
