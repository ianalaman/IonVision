# %%
from pathlib import Path
import sys

# Get the IonVision project directory (two levels up from current working dir)
PROJECT_DIR = Path.cwd().parent.parent
sys.path.append(str(PROJECT_DIR))

from energy_level_generator.render import generate_energy_levels

# %%
# Data directory inside the project
DATA_DIR = PROJECT_DIR / "energy_level_generator" / "data"

# JSON file paths
style_json_path = DATA_DIR / "sr_style.json"
energy_json_path = DATA_DIR / "SrSidebandCooling.json"

# %%
generate_energy_levels(energy_json_path, style_json_path)
