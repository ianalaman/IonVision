# %% [markdown]
# ## Importing the package (would work as pip install IonVision)

# %%
from pathlib import Path
import energy_level_generator as elg

PKG_ROOT = Path(elg.__file__).resolve().parents[1]  # look for package root
DATA = PKG_ROOT / "docs" / "how-to"

# %%
generate_energy_levels(DATA / "energy.json", DATA / "energy_style.json")
